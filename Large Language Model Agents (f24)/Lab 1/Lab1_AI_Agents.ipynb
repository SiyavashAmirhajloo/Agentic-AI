# %%
# !pip install -r /content/requirements.txt

# %%
# !pip install httpx

# %%
# %env SAMBANOVA_API_KEY=2bd5c63a-70c9-46a2-ae4e-8998294e59ea
# %env SAMBANOVA_BASE_URL=https://api.sambanova.ai/v1
# %env USE_AGENTIC=1
# %env AGENTIC_MODEL=Meta-Llama-3.1-8B-Instruct
# Out:
# env: SAMBANOVA_API_KEY=2bd5c63a-70c9-46a2-ae4e-8998294e59ea
# env: SAMBANOVA_BASE_URL=https://api.sambanova.ai/v1
# env: USE_AGENTIC=1
# env: AGENTIC_MODEL=Meta-Llama-3.1-8B-Instruct

# %%
import os
print(os.environ["SAMBANOVA_API_KEY"][:10])
# Out:
# 2bd5c63a-7

# %%
# !python3 /content/main.py "What is the overall score for taco bell?"
# Out:
# Taco Bell: 3.253
# Taco Bell: 3.253

# %%
# !python test.py
# Out:
# Test 1 Passed. Expected:  3.25 Query:  What is the overall score for taco bell?
# Test 2 Passed. Expected:  10.0 Query:  What is the overall score for In N Out?
# Test 3 Passed. Expected:  10.0 Query:  How good is the restaurant Chick-fil-A overall?
# Test 4 Passed. Expected:  8.94 Query:  What is the overall score for Krispy Kreme?
# 4/4 Tests Passed
